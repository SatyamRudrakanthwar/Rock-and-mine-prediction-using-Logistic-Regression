# %% [markdown]
# <a href="https://colab.research.google.com/github/SatyamRudrakanthwar/Rock-and-mine-prediction-using-Logistic-Regression/blob/main/Rock_and_mine_using_Logistic_Regression_Model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/Copy of sonar data.csv")
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df.isnull().sum()
# Out:
# 0.0200    0
# 0.0371    0
# 0.0428    0
# 0.0207    0
# 0.0954    0
#          ..
# 0.0180    0
# 0.0084    0
# 0.0090    0
# 0.0032    0
# R         0
# Length: 61, dtype: int64

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
df['R'].value_counts()
# Out:
# M    111
# R     96
# Name: R, dtype: int64

# %%
df.groupby(['R']).mean()
# Out:
#      0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# R
# M  0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R  0.022524  0.030232  0.035879  0.041664  0.061680  0.096199  0.113767
#
#      0.1601    0.3109    0.2111  ...    0.0232    0.0027    0.0065    0.0159  \
# R                                ...
# M  0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R  0.117153  0.135584  0.158785  ...  0.012198  0.010533  0.009673  0.009451
#
#      0.0072    0.0167    0.0180    0.0084    0.0090    0.0032
# R
# M  0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R  0.008581  0.007333  0.007708  0.006659  0.007058  0.006053
#
# [2 rows x 60 columns]

# %%
x = df.drop(columns=['R'], axis=1)
y = df['R']

# %%
len(y)
# Out:
# 207

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify= y, random_state=1)
print(x.shape, x_train.shape, x_test.shape)
print(x_train)
print(y_train)
# Out:
# (207, 60) (165, 60) (42, 60)
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 182  0.0096  0.0404  0.0682  0.0688  0.0887  0.0932  0.0955  0.2140  0.2546
# 27   0.0100  0.0275  0.0190  0.0371  0.0416  0.0201  0.0314  0.0651  0.1896
# 148  0.0207  0.0535  0.0334  0.0818  0.0740  0.0324  0.0918  0.1070  0.1553
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 67   0.0195  0.0142  0.0181  0.0406  0.0391  0.0249  0.0892  0.0973  0.0840
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 35   0.0094  0.0166  0.0398  0.0359  0.0681  0.0706  0.1020  0.0893  0.0381
# 139  0.0412  0.1135  0.0518  0.0232  0.0646  0.1124  0.1787  0.2407  0.2682
# 153  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 130  0.1150  0.1163  0.0866  0.0358  0.0232  0.1267  0.2417  0.2661  0.4346
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
#
# ...

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_train_prediction = lr.predict(x_train)
traning_data_accuracy = accuracy_score(x_train_prediction , y_train)
traning_data_accuracy
# Out:
# 0.8424242424242424

# %%
x_test_prediction = lr.predict(x_test)
traning_data_accuracy = accuracy_score(x_test_prediction , y_test)
traning_data_accuracy
# Out:
# 0.6666666666666666

# %%
input_data = (0.0307,0.0523,0.0653,0.0521,0.0611,0.0577,0.0665,0.0664,0.1460,0.2792,0.3877,0.4992,0.4981,0.4972,0.5607,0.7339,0.8230,0.9173,0.9975,0.9911,0.8240,0.6498,0.5980,0.4862,0.3150,0.1543,0.0989,0.0284,0.1008,0.2636,0.2694,0.2930,0.2925,0.3998,0.3660,0.3172,0.4609,0.4374,0.1820,0.3376,0.6202,0.4448,0.1863,0.1420,0.0589,0.0576,0.0672,0.0269,0.0245,0.0190,0.0063,0.0321,0.0189,0.0137,0.0277,0.0152,0.0052,0.0121,0.0124,0.0055)


changing_inputdata_as_numpyarray = np.asarray(input_data)
reshape_data_of_input_data = changing_inputdata_as_numpyarray.reshape(1, -1)

predict = lr.predict(reshape_data_of_input_data)
# print(predict)


if (predict[0]== 'R'):
  print("Rock is found")
else:
  print("mine is found")
# Out:
# Rock is found
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
